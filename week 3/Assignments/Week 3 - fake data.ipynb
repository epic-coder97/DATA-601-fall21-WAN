# %% [markdown]
# ## week 3: fake data
#
# #### Assignment Content
#
# Write a Python notebook that generates a file containing the following data:​ ​
# <ol>
#     <li>Email addresses​. Must have an "@"</li>
# <li>Phone numbers​</li>
# <li>Home Address​</li>
# <li>Person's name​</li>
# <li>Year born. Use realistic values.​</li>
# <li>Number of kids. Use realistic values.​</li>
# <li>Categorical variable: rent or own?​</li>
# <li>Annual income. Optional challenge: Use a non-uniform distribution​</li>
# <li>Number of speeding tickets in past year. Optional challenge: Use a non-uniform distribution​</li>
# <li>The user of your notebook should be able to specify how many entities are to be generated.​ ​</li>
#     </ol>
#
# <i>Do not include the .csv output file in your submission -- the file should be generated dynamically.
#
# Order of columns in CSV is not relevant. ​
#
# See slides in lecture for tips.</i>

# %%
pip install faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from faker.providers.person.en import Provider

# %%
from faker import Faker

fake = Faker()

# %%
for _ in range(10):
   print(fake.name())
# Out:
# Alyssa Bender
# Lisa Oneal
# John Martinez
# Phyllis Martinez
# Jordan Stewart
# Kimberly Lewis
# Cynthia Jackson
# Debra Ray
# Andrea Burton
# Darrell Taylor

# %%
generateProfile = Faker()

generateProfile.simple_profile()
# Out:
# {'username': 'chunt',
#  'name': 'Jennifer Harmon',
#  'sex': 'F',
#  'address': '029 Michelle Greens\nChristopherborough, PA 39387',
#  'mail': 'alyssa95@yahoo.com',
#  'birthdate': datetime.date(1920, 4, 13)}

# %%
generateProfile.profile()
# Out:
# {'job': 'Producer, radio',
#  'company': 'Zamora Inc',
#  'ssn': '042-91-7689',
#  'residence': '302 Norton Stravenue\nMatthewshire, ND 27131',
#  'current_location': (Decimal('-69.0064925'), Decimal('-149.260623')),
#  'blood_group': 'O-',
#  'website': ['https://moore.com/',
#   'https://cruz-nguyen.com/',
#   'https://www.hale.biz/',
#   'https://www.sims.com/'],
#  'username': 'emcdonald',
#  'name': 'Joseph Valenzuela',
#  'sex': 'M',
#  'address': '3007 Thompson Islands Suite 001\nSandovalmouth, NM 45633',
#  'mail': 'bradley14@yahoo.com',
#  'birthdate': datetime.date(1969, 4, 4)}

# %%
import pandas as pd 

generateProfile = Faker()

# generate 1000 profiles 
data = [generateProfile.profile() for i in range(1000)]

# save profiles in pandas dataframe
df = pd.DataFrame(data)

df
# Out:
#                                     job                         company  \
# 0                           Firefighter                       Noble Ltd
# 1              Surveyor, rural practice                     Garza-Smith
# 2    Tourist information centre manager                       Riggs Inc
# 3                   Early years teacher  Friedman, Crawford and Vasquez
# 4                              Animator               Wilkinson-Jackson
# ..                                  ...                             ...
# 995          Research scientist (maths)    Phillips, Harris and Johnson
# 996   Radiation protection practitioner                      Wilson LLC
# 997               Aeronautical engineer                 Charles-Sanchez
# 998          Contracting civil engineer                  Williams Group
# 999            Surveyor, land/geomatics    Pope, Franklin and Maldonado
#
#              ssn                                          residence  \
# ...

# %%
import random

# %%
#email address domain
 
email_data = ["@gmail.com", "@yahoo.com", "@hotmail.com", "@aol.com", "@outlook.com"]
 
print(random.choice(data))
# Out:
# @aol.com

# %%
a = fake.name()
print(a)
#generating realistic email from name
e = a.replace(" ", "") + random.choice(email_data)
print(e)
addr = fake.address()
phno = fake.phone_number()
#dir(fake)
print(addr)
print(phno)
# Out:
# Samantha Barber
# SamanthaBarber@gmail.com
# Unit 7951 Box 6221
# DPO AP 41254
# 001-471-216-0724

# %%
dir(fake)
# Out:
# ['__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_factories',
#  '_factory_map',
#  '_locales',
#  '_map_provider_method',
#  '_select_factory',
#  '_unique_proxy',
#  '_weights',
#  'aba',
#  'add_provider',
#  'address',
#  'administrative_unit',
#  'am_pm',
#  'android_platform_token',
#  'ascii_company_email',
#  'ascii_email',
#  'ascii_free_email',
#  'ascii_safe_email',
#  'bank_country',
#  'bban',
#  'binary',
#  'boolean',
#  'bothify',
#  'bs',
#  'building_number',
#  'cache_pattern',
#  'catch_phrase',
#  'century',
#  'chrome',
# ...

# %%
from datetime import date 
dob = fake.date_of_birth(tzinfo=None, minimum_age=24, maximum_age=75)
print(dob)
today = date.today()
age = today.year - dob.year - ((today.month, today.day) < (dob.month, dob.day))
print(age)
if age < 30 :
    kids = random.randrange(0,2,1)
elif age > 30 and age < 40:
    kids = random.randrange(0,4,1)
else : 
    kids = random.randrange(0,5,1)
    
print("kids :", kids)
# Out:
# 1981-11-21
# 39
# kids : 1

# %%
#MEDIAN HOUSE HOLD INCOME IS $64,000
income = random.randrange(63000 , 380000 ,9000)
print("$",income)

if income > 150000:
    house = "own"
else:
    house = "rent"
    
print ("house : " , house)

# %%
#speeding ticket 

s_ticket = random.randrange(0 , 10 , 1)
print("speeding Ticket :",s_ticket)
# Out:
# speeding Ticket : 2

# %%
for i in range(100):
    print(fake.phone_number())
# Out:
# 001-907-148-8539
# 095-305-1163x189
# 612-100-7355x1592
# 410.923.0997x95435
# 439.474.9096x0190
# +1-388-389-7423
# 787.008.4624
# (599)403-2039x15772
# 001-743-339-8997
# +1-990-007-3358x62350
# 001-082-118-7787x0766
# (096)228-7253
# 001-838-925-9781x4210
# (157)546-7855x3246
# 001-267-556-2771
# 001-336-643-5422x777
# +1-794-608-3217
# 145-158-2675x8290
# 522-724-7259x714
# 434.885.9247
# +1-965-293-1401x6990
# (126)033-2996x437
# 001-108-747-7208x34717
# 1325143878
# (991)172-8943x852
# 835.003.5220
# 142.732.8440
# (400)493-3092x228
# 424-549-7264x30429
# +1-248-760-6217
# 282.139.8662
# (480)096-0641x3233
# 962-569-8162x388
# 189.182.9039x1265
# +1-278-653-1488
# (033)623-7804x11131
# +1-997-048-0535x9376
# 186-521-1707x62225
# 843.241.6114
# 001-665-640-6043
# (343)922-2369x55239
# 8235532512
# 965-944-3670x757
# (657)777-2352
# +1-760-984-4986x3437
# 1644476692
# 120-773-4585
# 701-811-8784
# 354-035-9336
# 400.528.4784
# 118-566-1897x0595
# 001-102-614-1352x7037
# ...
