# %%
import pandas as pd
print('pandas',pandas.__version__)

import time
# Out:
# pandas 1.3.3

# %%
# please use .head() or .tail() rather than viewing the entire dataframe
pandas.set_option("display.max_rows", 999)
pandas.set_option("display.max_columns", 999)

# %% [markdown]
# # data 1
# https://data.ny.gov/Energy-Environment/Solid-Waste-Management-Facilities/2fni-raj8

# %%
df1 = pandas.read_csv('https://data.ny.gov/api/views/2fni-raj8/rows.csv?accessType=DOWNLOAD&sorting=true')
df1.shape
# Out:
# (2794, 22)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 47 to 2734
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Facility Name             22 non-null     object
#  1   Location Address          22 non-null     object
#  2   Location Address2         22 non-null     object
#  3   City                      22 non-null     object
#  4   State                     22 non-null     object
#  5   Zip Code                  22 non-null     object
#  6   County                    22 non-null     object
#  7   Region                    22 non-null     int64
#  8   Phone Number              22 non-null     float64
#  9   Owner Name                22 non-null     object
#  10  Owner Type                22 non-null     object
#  11  Activity Desc             22 non-null     object
#  12  Activity Number           22 non-null     object
#  13  Active                    22 non-null     object
#  14  East Coordinate           22 non-null     int64
#  15  North Coordinate          22 non-null     int64
#  16  Accuracy Code             22 non-null     object
#  17  Waste Types               22 non-null     object
#  18  Authorization Number      22 non-null     object
#  19  Authorization Issue Date  22 non-null     object
#  20  Expiration Date           22 non-null     object
#  21  Georeference              22 non-null     object
# dtypes: float64(1), int64(3), object(18)
# memory usage: 4.0+ KB

# %% [markdown]
# ### Is this data tidy or not?
#
# (Yes or no)
#
# Ans:  <b>NO</b>
#
# *if the data is not tidy, then convert the data to a tidy dataframe*

# %%
# droping null values
df1.isna().sum()
df1.dropna(how='any', inplace=True)

#phone number is stored as a float value
df1['Phone Number'] = df1['Phone Number'].astype(int)
df1
# Out:
#                            Facility Name               Location Address  \
# 47                 Empire Recycling Corp         1101 West Clark Street
# 53                       C. L. McCormack                5885 Jordan Rd.
# 168     Cardinal Health Nuclear Pharmacy                303 Cayuga Road
# 221          Tyrone (T) Recycling Center             435 County Road 23
# 751                 Hooper's Tire Outlet              503 Gordon Avenue
# 894   Syracuse Haulers Waste Removal Inc             6223 Thompson Road
# 1040             Rochester Recycling LLC                851 West Avenue
# 1046           Peconic Auto Wreckers Inc           196A Montauk Highway
# 1064             Corazzini Asphalt; Inc.                  6245 Cox Lane
# 1155                      S&P Sanitation           1062 Montauk Highway
# 1654             Corazzini Asphalt; Inc.                  6245 Cox Lane
# 1785                     Bob's Used Cars      6 Tuscarora St. (mailing)
# 1942         Nuclear Diagnostic Products          130 Commercial Street
# 1943                  Gilbert Excavating             685 County Route 3
# 2059             Corazzini Asphalt; Inc.                  6245 Cox Lane
# 2111             Potter Transfer Station  1250 Phelps Road (DPW Garage)
# 2134         Tyrone (T) Recycling Center             435 County Road 23
# 2199                      S&P Sanitation           1062 Montauk Highway
# 2441   City of Syracuse DPW - Lowes Site      2800-3400 Burnet Ave Rear
# 2622                      Laing Trucking               133 Hoffman Road
# 2669              Stiles Used Auto Parts              11 Old State Road
# 2734  Syracuse Haulers Waste Removal Inc             6223 Thompson Road
#
#                     Location Address2             City State Zip Code  \
# 47                           Bldg. 38         Endicott    NY    13760
# 53                     5739 Fikes Rd.         Elbridge    NY    13060
# 168                         Suite 200      Cheektowaga    NY    14223
# 221              3600 State Route 226           Tyrone    NY    14837
# 751                           Suite 1         Syracuse    NY    13208
# 894                        Suite 1000         Syracuse    NY    13206
# 1040                      Building 17        Rochester    NY    14611
# 1046                      P.O. Box 39           Speonk    NY    11972
# 1064                    P.O. Box 1281        Cutchogue    NY    11935
# 1155                       PO Box 939        Watermill    NY    11976
# 1654                    P.O. Box 1281        Cutchogue    NY    11935
# 1785    2270 Williams Road (facility)          Addison    NY    14801
# 1942                          Suite 1        Plainview    NY    11883
# 1943                          Lot 009           Fulton    NY    13069
# 2059                    P.O. Box 1281        Cutchogue    NY    11935
# 2111  1226 Phelps Road (Town Offices)        Middlesex    NY    14507
# 2134             3600 State Route 226           Tyrone    NY    14837
# 2199                       PO Box 939        Watermill    NY    11976
# 2441    (Simon Drive - next to Lowes)         Syracuse    NY    13210
# 2622                 Town of Guilford       Bainbridge    NY    13733
# 2669                       PO Box 163  Dekalb Junction    NY    13630
# 2734                       Suite 1000         Syracuse    NY    13206
#
#             County  Region  Phone Number                   Owner Name  \
# 47          Broome       7   -2147483648             Empire Recycling
# 53        Onondaga       7   -2147483648   Melanie & Meghan McCormack
# 168           Erie       9   -2147483648     Cardinal Health 414; LLC
# 221       Schuyler       8   -2147483648               Town of Tyrone
# 751       Onondaga       7   -2147483648                Daniel Hooper
# 894       Onondaga       7   -2147483648              Rocco A. Grosso
# 1040        Monroe       8   -2147483648                Mark Schartau
# 1046       Suffolk       1   -2147483648                 Glenn Clarke
# 1064       Suffolk       1   -2147483648      Corazzini Asphalt; Inc.
# 1155       Suffolk       1   -2147483648           Suzanne Hennington
# 1654       Suffolk       1   -2147483648      Corazzini Asphalt; Inc.
# 1785       Steuben       8   -2147483648              Robert Hamilton
# 1942        Nassau       1   -2147483648  Nuclear Diagnostic Products
# 1943        Oswego       7   -2147483648                 John Gilbert
# 2059       Suffolk       1   -2147483648      Corazzini Asphalt; Inc.
# 2111         Yates       8   -2147483648             Joseph E. Gibson
# 2134      Schuyler       8   -2147483648               Town of Tyrone
# 2199       Suffolk       1   -2147483648           Suzanne Hennington
# 2441      Onondaga       7   -2147483648             City of Syracuse
# 2622      Chenango       7   -2147483648                Paul J. Laing
# 2669  St. Lawrence       6   -2147483648                  Rick Stiles
# 2734      Onondaga       7   -2147483648              Rocco A. Grosso
#
#      Owner Type                                      Activity Desc  \
# 47      Private           RHRF - greater than 5 tpd - registration
# 53      Private          Land application - septage - registration
# 168     Private          RMW - radiological storage - registration
# 221   Municipal                RHRF - 5 tpd or less - registration
# 751     Private                      WTHRF - seller - registration
# 894     Private                                      RHRF - permit
# 1040    Private           RHRF - greater than 5 tpd - registration
# 1046    Private                         VDF - large - registration
# 1064    Private  CDDHRF - asphalt pavement and millings - regis...
# 1155    Private                                      RHRF - permit
# 1654    Private        CDDHRF - concrete rock brick - registration
# 1785    Private   Motor vehicle repair shop - large - registration
# 1942    Private          RMW - radiological storage - registration
# 1943    Private          Land application - septage - registration
# 2059    Private  CDDHRF - uncontaminated soil sand gravel rock ...
# 2111    Private                   Transfer facility - registration
# 2134  Municipal                   Transfer facility - registration
# 2199    Private                                    CDDHRF - permit
# 2441  Municipal                    Mulch processing - registration
# 2622    Private                RHRF - 5 tpd or less - registration
# 2669    Private                         VDF - large - registration
# 2734    Private                         Transfer facility - permit
#
#      Activity Number Active  East Coordinate  North Coordinate  \
# 47        [04R20019]    Yes           420884           4662787
# 53        [34A40010]    Yes           386132           4765162
# 168       [15J10037]    Yes           194546           4760820
# 221       [49R10003]    Yes           328966           4698771
# 751       [34W20076]    Yes           407324           4771556
# 894       [34RP0065]    Yes           411227           4769461
# 1040      [28R20005]    Yes           283500           4780600
# 1046      [52V50278]    Yes           694161           4521469
# 1064      [52C20280]    Yes           710319           4545262
# 1155        [52W116]    Yes           723442           4533029
# 1654      [52C10280]    Yes           710319           4545262
# 1785      [51V40064]    Yes           304336           4664585
# 1942      [30J10134]    Yes           629639           4516718
# 1943      [38A40010]    Yes           386400           4797282
# 2059      [52C60280]    Yes           710319           4545262
# 2111      [62T10016]    Yes           318868           4730397
# 2134      [49T10003]    Yes           328966           4698771
# 2199        [52W116]    Yes           723442           4533029
# 2441      [34M10013]    Yes           410406           4767657
# 2622      [09R10012]    Yes           458559           4690258
# 2669      [45V50008]    Yes           478493           4928428
# 2734      [34TP0065]    Yes           411227           4769461
#
#                                           Accuracy Code  \
# 47                               4.1 - Address Matching
# 53    1.1 - Obtained from original submission and un...
# 168   4.2 - Utilization of GIS and existing spatial ...
# 221                              1 - No accuracy stated
# 751                              4.1 - Address Matching
# 894                              4.1 - Address Matching
# 1040  4.2 - Utilization of GIS and existing spatial ...
# 1046      4.3 - Utilization of Digital Orthophoto Quads
# 1064      4.3 - Utilization of Digital Orthophoto Quads
# 1155      4.3 - Utilization of Digital Orthophoto Quads
# 1654      4.3 - Utilization of Digital Orthophoto Quads
# 1785  4.2 - Utilization of GIS and existing spatial ...
# 1942      4.3 - Utilization of Digital Orthophoto Quads
# 1943      4.3 - Utilization of Digital Orthophoto Quads
# 2059      4.3 - Utilization of Digital Orthophoto Quads
# 2111                             4.1 - Address Matching
# 2134                             1 - No accuracy stated
# 2199      4.3 - Utilization of Digital Orthophoto Quads
# 2441                             4.1 - Address Matching
# 2622                             4.1 - Address Matching
# 2669                             4.1 - Address Matching
# 2734                             4.1 - Address Matching
#
#                                             Waste Types Authorization Number  \
# 47    Paper/Cardboard;Wood (Pallets & Crates);Plasti...             04R20019
# 53                                              Septage             34A40010
# 168                 Regulated Medical Waste;Radioactive             15J10037
# 221   Commingled Containers;Commingled Paper;Contain...             49R10003
# 751                                                Tire             34W20076
# 894   Source Separated Recyclables (Metal/Glass/Pape...   7-3126-00070/00039
# 1040  Plastics;Office Paper;Metals (Ferrous);Metals ...             28R20005
# 1046                               End of Life Vehicles             52V50278
# 1064                                            Asphalt             52C10280
# 1155                   Paper/Cardboard;Commingled Paper   1-4736-06027/00001
# 1654                                      Concrete;Rock             52C10280
# 1785                               End of Life Vehicles             51V40064
# 1942                                        Radioactive             30J10134
# 1943                                            Septage             38A40010
# 2059                           Soil (Clean);Sand;Gravel             52C10280
# 2111  MSW (Residential/Institutional & Commercial);S...             62T10016
# 2134  MSW (Residential/Institutional & Commercial);C...             49T10003
# 2199  Construction & Demolition Debris;Wood (Brush/ ...   1-4736-06027/00001
# 2441              Wood (Brush/ Branches/ Trees/ Stumps)             34M10013
# 2622  Paper/Cardboard;Newspaper;Metals (Non-Ferrous)...             09R10012
# 2669                               End of Life Vehicles             45V50008
# 2734  Construction & Demolition Debris;Metals (Ferro...   7-3126-00070/00039
#
#      Authorization Issue Date Expiration Date  \
# 47                 10/18/2018      05/03/2023
# 53                 07/03/2019      07/03/2024
# 168                03/13/2019      03/13/2024
# 221                05/10/2018      05/09/2023
# 751                01/17/2019      01/16/2024
# 894                01/03/2019      01/02/2029
# 1040               01/18/2019      01/17/2024
# 1046               07/11/2019      07/10/2024
# 1064               07/02/2019      07/01/2024
# 1155               01/17/2018      01/16/2023
# 1654               07/02/2019      07/01/2024
# 1785               09/16/2019      09/15/2024
# 1942               11/18/2020      11/17/2025
# 1943               07/13/2018      05/03/2023
# 2059               07/02/2019      07/01/2024
# 2111               10/21/2019      10/20/2024
# 2134               05/10/2018      05/09/2023
# 2199               01/17/2018      01/16/2023
# 2441               06/26/2018      06/26/2023
# 2622               05/04/2018      05/04/2023
# 2669               11/15/2019      11/14/2024
# 2734               01/03/2019      01/02/2029
#
#                                            Georeference
# 47    1101 West Clark Street\nEndicott, NY 13760\n(4...
# 53    5885 Jordan Rd.\nElbridge, NY 13060\n(43.05531...
# 168   303 Cayuga Road\nCheektowaga, NY 14223\n(42.93...
# 221   435 County Road 23\nTyrone, NY 14837\n(42.4217...
# 751   503 Gordon Avenue\nSyracuse, NY 13208\n(43.091...
# 894   6223 Thompson Road\nSyracuse, NY 13206\n(43.07...
# 1040  851 West Avenue\nRochester, NY 14611\n(43.1496...
# 1046  196A Montauk Highway\nSpeonk, NY 11972\n(40.81...
# 1064  6245 Cox Lane\nCutchogue, NY 11935\n(41.032199...
# 1155  1062 Montauk Highway\nWatermill, NY 11976\n(40...
# 1654  6245 Cox Lane\nCutchogue, NY 11935\n(41.032199...
# 1785  6 Tuscarora St. (mailing)\nAddison, NY 14801\n...
# 1942  130 Commercial Street\nPlainview, NY 11883\n(4...
# 1943  685 County Route 3\nFulton, NY 13069\n(43.3260...
# 2059  6245 Cox Lane\nCutchogue, NY 11935\n(41.032199...
# 2111  1250 Phelps Road (DPW Garage)\nMiddlesex, NY 1...
# 2134  435 County Road 23\nTyrone, NY 14837\n(42.4217...
# 2199  1062 Montauk Highway\nWatermill, NY 11976\n(40...
# 2441  2800-3400 Burnet Ave Rear\nSyracuse, NY 13210\...
# 2622  133 Hoffman Road\nBainbridge, NY 13733\n(42.36...
# 2669  11 Old State Road\nDekalb Junction, NY 13630\n...
# 2734  6223 Thompson Road\nSyracuse, NY 13206\n(43.07...

# %% [markdown]
# # data 2
# https://data.ny.gov/Energy-Environment/Gasoline-Retail-Prices-Weekly-Average-by-Region-Be/nqur-w4p7/data

# %%
df2 = pandas.read_csv('https://data.ny.gov/api/views/nqur-w4p7/rows.csv?accessType=DOWNLOAD&sorting=true')
df2.shape
# Out:
# (679, 18)

# %% [raw]
# ### Is this data tidy or not?
#
# (Yes or no)
#
# *if the data is not tidy, then convert the data to a tidy dataframe*

# %% [markdown]
# # data 3
# https://catalog.data.gov/dataset/department-of-state-business-filings-beginning-1991

# %%
df4 = pandas.read_csv('https://data.ny.gov/api/views/m7i3-tv6j/rows.csv?accessType=DOWNLOAD')
df4.shape
# Out:
# (10440, 24)

# %% [markdown]
# ### Is this data tidy or not?
#
# (Yes or no)
#
# *if the data is not tidy, then convert the data to a tidy dataframe*

# %% [markdown]
# # data 4
# https://catalog.data.gov/dataset/new-york-city-leading-causes-of-death-ce97f

# %%
df6 = pandas.read_csv('https://data.cityofnewyork.us/api/views/jb7j-dtam/rows.csv?accessType=DOWNLOAD')
df6.shape
# Out:
# (1094, 7)

# %% [markdown]
# ### Is this data tidy or not?
#
# (Yes or no)
#
# *if the data is not tidy, then convert the data to a tidy dataframe*

# %% [markdown]
# # data 5
# https://www.briandunning.com/sample-data/<BR>
# https://www.briandunning.com/sample-data/us-500.zip

# %% [markdown]
# You may need to install the "zipfile" library using either pip or conda

# %% [raw]
# # https://pypi.org/project/zipfile36/
# !pip install zipfile36

# %% [raw]
# # https://anaconda.org/anaconda/zipfile36
# conda install -c anaconda zipfile36

# %%
import requests, zipfile, io

# %%
zip_file_url = 'https://www.briandunning.com/sample-data/us-500.zip'

# %%
# source: https://stackoverflow.com/a/14260592/1164295
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
df6 = pandas.read_csv('us-500.csv')

# %% [markdown]
# ### Is this data tidy or not?
#
# (Yes or no)
#
# *if the data is not tidy, then convert the data to a tidy dataframe*

# %% [markdown]
# <!--
# Hidden bonus question!
#
# This is optional, not required, and not part of the graded assignment
#
# # data 6
# https://data.cdc.gov/NNDSS/NNDSS-Table-II-Lyme-disease-to-Meningococcal/y6uv-t34t
# -->

# %% [markdown]
# <!--
# WARNING: THIS IS A HARD CHALLENGE.
# I recommend not spending more than 1 hour on this.
#
# df6 = pandas.read_csv('https://data.cdc.gov/api/views/y6uv-t34t/rows.csv?accessType=DOWNLOAD')
# df6.shape
# -->
