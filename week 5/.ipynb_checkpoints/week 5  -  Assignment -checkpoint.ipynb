# %% [markdown]
# ## Week 5: openpyxl
# Assignment Content
#
# You get an Excel spreadsheet that has two worksheets, "patient info" and "records"​
# <ol>
# <li>Each worksheet has data and visualizations and formulas</li>
# <li>Each row in each worksheet represents information associated with a single person.. ​</li>
# <li>Worksheet "patient info" has a "patient id" column; ​</li>
# <li>Worksheet "records" has a "p_id" column​</li>
# <li>The "patient id" values in "patient info" tab are the same variable as "p_id" in "records". Some people have information on both sheets, while other people have information only on one sheet
# Use openpyxl to copy information about patients from "records" to "patient info"​. Submit a notebook that reads the Excel <li>spreadsheet and produces a separate Excel file with the following modifications:​</li>
#
# <li>For each patient identified by "p_id" listed in the "records" sheet that don't exist in "patient info," create a new row in "patient info". The row from "records" should be copied to the row in "patient info."</li>
# <li>For each patient listed in the "records" sheet where "p_id" appears "patient info" under "patient id," copy the data in the row from records to "patient info" sheet</li>
# <li>Make no changes to the visualizations that exist in each worksheet​</li>
# <li>Make no changes to the data in the "records"​ sheet</li>
# <li>Write your changes to a new .xlsx file (don't overwrite the original)​ ​</li>
#     </ol>
# <b>Observations:​</b>
#
# <li>"patient info" worksheet will have new columns (because those new columns exist in the "records" worksheet)​</li>
# <li>"patient info" worksheet will have new rows (one new row per patient)​</li>
# <li>There will be empty cells in "patient info" worksheet​</li>
# <li>Use a programmatic (rather than manual) approach to identify which patients appear in both worksheets​</li>
# <li>Some cells in both worksheets contain formulas. Copy only values from "records" to "patient info"​</li>
#
# When you are done with the assignment or have spent an hour on the homework (whichever comes first), please send me an email indicating which of these you have reached​ ​
#
# To: jhwan@umbc.edu​
#
# Subject: Data 601 Fall 2020 Week 5: openpyxl
#
# Examples of content: "I have spent 1 hour on the homework" or "I am done with the assignment in 20 minutes."​
#
# If you've not completed the homework, please specify what your status is.​

# %%
import openpyxl 
import pandas as pd

# %%
#week_05_homework_XLSX_openpyxl
wb = openpyxl.load_workbook('week_05_homework_XLSX_openpyxl.xlsx')
sheet_name = []
#storing sheet names in a list so I can later call them using index numbers
sheet_name = wb.sheetnames
#calling sheet names by index
print(sheet_name[1])

#printing all sheets
print(sheet_name)
# Out:
# records
# ['patient info', 'records']

# %%
sheet = wb[sheet_name[1]] # calling records
#storing records in dataframe
df = pd.DataFrame(sheet.values)
df
# Out:
#          0       1   2    3         4     5       6          7        8   \
# 0      p_id     nam  kf  ave  mginasdf  imim  ifasdm  ignghasdf  ignghim
# 1     45186  qiuecr  33   11    qbyekt     2      38       1022      527
# 2     54257  jahnuf  74   11    pitpiy     1      28       1028      184
# 3     86960  scrffw  28   10    ncyeyq     2      37       1024     1087
# 4     38965  rmxksw  98   11    ffqedp     1      19       1005      957
# ...     ...     ...  ..  ...       ...   ...     ...        ...      ...
# 1196  83071  xvmaoh  86    9    yevpmr     1      16       1010      222
# 1197  23735  slrxoi  22    9    gyoqsk     1      36       1008      995
# 1198  11338  maripf  92   10    mwfthr     1      30       1031       72
# 1199  27315  pdbjgp  45   11    jekbbu     2      36       1032      148
# 1200  72787  npscwt  76   11    lmdmmm     1       9       1001      331
#
#             9   ...               19           20        21      22  \
# 0     iimghhai  ...  aifaignaghgjaga  miadgfadnaa   agaogsf  avavag
# 1       fokyjc  ...               98     0.113047  0.442579  kvuydu
# 2       lykduc  ...              107      0.73472  0.008616  yhnxac
# 3       rfeobz  ...              210     0.242925  0.895781  lchzux
# 4       zjsjup  ...              103     0.143863  0.991214  wsghni
# ...        ...  ...              ...          ...       ...     ...
# 1196    rqsiup  ...              215     0.866245  0.050796  svnedm
# 1197    bhrrvg  ...              109     0.788453  0.813866  xtlywm
# 1198    hnjaff  ...               65     0.444706  0.598433  dafcvx
# 1199    hbqzjw  ...               48     0.042877  0.938969  haeapj
# 1200    vpycbv  ...              161     0.898994  0.441909  jqcysj
#
#               23               24             25              26  \
# 0     agavcagaad  mdifa asdfi asf  sfaisf g adfa  mg adfa gasf a
# 1       0.504722         0.612495       0.275035        0.116697
# 2       0.435496         0.392883       0.795665        0.505723
# 3       0.589458         0.344104       0.104604        0.347974
# 4       0.153842         0.353898       0.246882        0.777188
# ...          ...              ...            ...             ...
# 1196    0.058985         0.514319       0.787371        0.453244
# 1197     0.37276         0.158463       0.286107        0.472504
# 1198    0.317029         0.479107       0.785905        0.858837
# 1199    0.774384         0.154361       0.789817        0.092309
# 1200    0.142884         0.175055       0.860159        0.543864
#
#                 27     28
# 0     fads adsfas   dfmga
# 1         0.661027    135
# 2         0.000247    174
# 3         0.338182     60
# 4         0.773037     27
# ...            ...    ...
# 1196      0.262793    200
# 1197      0.368032     36
# 1198      0.044693    219
# 1199      0.972039    229
# 1200      0.018342    183
#
# [1201 rows x 29 columns]

# %%
sheet.cell(row=1, column=1).value
# Out:
# 'p_id'

# %%
for row_indx in range(1,5):
    print(row_indx, sheet.cell(row=row_indx, column=1).value)
# Out:
# 1 p_id
# 2 45186
# 3 54257
# 4 86960

# %%
p_id = []
type(p_id)       
for row in range(2, sheet.max_row + 1):
    p_id  = sheet['A' + str(row)].value
    #print(p_id)
type(p_id)
# Out:
# int

# %%
import pandas as pd
p_info = pd.read_excel("week_05_homework_XLSX_openpyxl.xlsx", sheet_name=[sheet_name[1]])

# %%
print(p_info)
# Out:
# {'records':        p_id     nam  kf  ave mginasdf  imim  ifasdm  ignghasdf  ignghim  \
# 0     45186  qiuecr  33   11   qbyekt     2      38       1022      527
# 1     54257  jahnuf  74   11   pitpiy     1      28       1028      184
# 2     86960  scrffw  28   10   ncyeyq     2      37       1024     1087
# 3     38965  rmxksw  98   11   ffqedp     1      19       1005      957
# 4     66614  zvyicl  48   10   drmaxo     2      14       1018      969
# ...     ...     ...  ..  ...      ...   ...     ...        ...      ...
# 1195  83071  xvmaoh  86    9   yevpmr     1      16       1010      222
# 1196  23735  slrxoi  22    9   gyoqsk     1      36       1008      995
# 1197  11338  maripf  92   10   mwfthr     1      30       1031       72
# 1198  27315  pdbjgp  45   11   jekbbu     2      36       1032      148
# 1199  72787  npscwt  76   11   lmdmmm     1       9       1001      331
#
#      iimghhai  ...  aifaignaghgjaga  miadgfadnaa   agaogsf  avavag  \
# 0      fokyjc  ...               98     0.113047  0.442579  kvuydu
# 1      lykduc  ...              107     0.734720  0.008616  yhnxac
# 2      rfeobz  ...              210     0.242925  0.895781  lchzux
# 3      zjsjup  ...              103     0.143863  0.991214  wsghni
# 4      cksvjw  ...               70     0.823156  0.406428  mgcfgj
# ...       ...  ...              ...          ...       ...     ...
# 1195   rqsiup  ...              215     0.866245  0.050796  svnedm
# 1196   bhrrvg  ...              109     0.788453  0.813866  xtlywm
# 1197   hnjaff  ...               65     0.444706  0.598433  dafcvx
# 1198   hbqzjw  ...               48     0.042877  0.938969  haeapj
# 1199   vpycbv  ...              161     0.898994  0.441909  jqcysj
#
#       agavcagaad  mdifa asdfi asf  sfaisf g adfa mg adfa gasf a  fads adsfas   \
# 0       0.504722         0.612495       0.275035       0.116697      0.661027
# 1       0.435496         0.392883       0.795665       0.505723      0.000247
# 2       0.589458         0.344104       0.104604       0.347974      0.338182
# 3       0.153842         0.353898       0.246882       0.777188      0.773037
# 4       0.270382         0.428908       0.231510       0.631235      0.692844
# ...          ...              ...            ...            ...           ...
# 1195    0.058985         0.514319       0.787371       0.453244      0.262793
# 1196    0.372760         0.158463       0.286107       0.472504      0.368032
# 1197    0.317029         0.479107       0.785905       0.858837      0.044693
# 1198    0.774384         0.154361       0.789817       0.092309      0.972039
# 1199    0.142884         0.175055       0.860159       0.543864      0.018342
#
#       dfmga
# 0       135
# 1       174
# 2        60
# 3        27
# 4       222
# ...     ...
# 1195    200
# 1196     36
# 1197    219
# 1198    229
# 1199    183
#
# [1200 rows x 29 columns]}
