# %% [markdown]
# ## week 2: CSV and Pandas
#
# Download data in CSV format from one of the following sites: here or here. Load the data into a Pandas dataframe. Use Pandas to count the number of rows of data and number of columns. Display the first 8 rows of the dataframe. Display the bottom 3 rows of the dataframe. Display the transpose of the first 4 rows.
#
# Your selection of a CSV should have at least 2 columns and at least 10 rows. Include a link to the data source in the Juptyer notebook you submit.
#
# #### Modification for advanced students:
#
#  Load CSV from URL using Pandas or request or another library
#
#  CSV file Link : https://support.spatialkey.com/wp-content/uploads/2021/02/Sacramentorealestatetransactions.csv

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-1.3.2-cp39-cp39-win_amd64.whl (10.2 MB)
# ...
#   Using cached numpy-1.21.2-cp39-cp39-win_amd64.whl (14.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
#  CSV file Link : https://support.spatialkey.com/wp-content/uploads/2021/02/Sacramentorealestatetransactions.csv

# %% [markdown]
# ### loading data in dataframe df

# %%
#loading data in dataframe df
df = pd.read_csv('Sacramentorealestatetransactions.csv')
#displaying dataframe
df
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %% [markdown]
# ###  counting Rows and Column

# %%
#counting Rows and Column
df.shape #rows x column
# Out:
# (985, 12)

# %%
df.info() # info() provides the essential details about dataset, such as the number of rows and columns, etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %% [markdown]
# ### displaying 1st 8 rows i.e. from 0 to 7

# %%
#displaying 1st 8 rows i.e. from 0 to 7
df.head(8)
# Out:
#                 street        city    zip state  beds  baths  sq__ft  \
# 0         3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1          51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2       2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3     2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4      6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
# 5   5828 PEPPERMILL CT  SACRAMENTO  95841    CA     3      1    1122
# 6  6048 OGDEN NASH WAY  SACRAMENTO  95842    CA     3      2    1104
# 7        2561 19TH AVE  SACRAMENTO  95820    CA     3      1    1177
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# ...

# %% [markdown]
# ### displaying bottom 3 rows

# %%
#displaying bottom 3 rows
df.tail(3)
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type                     sale_date   price   latitude   longitude
# 982  Residential  Thu May 15 00:00:00 EDT 2008  235000  38.708824 -121.256803
# 983  Residential  Thu May 15 00:00:00 EDT 2008  235301  38.417000 -121.397424
# 984  Residential  Thu May 15 00:00:00 EDT 2008  235738  38.655245 -121.075915

# %% [markdown]
# ### Display the transpose of the first 4 rows

# %%
#copying first 4 rows in new data frame
df2 = df[0:4]
df2
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146

# %%
df2t = df2.T
df2t
# Out:
#                                       0                             1  \
# street                     3526 HIGH ST                   51 OMAHA CT
# city                         SACRAMENTO                    SACRAMENTO
# zip                               95838                         95823
# state                                CA                            CA
# beds                                  2                             3
# baths                                 1                             1
# sq__ft                              836                          1167
# type                        Residential                   Residential
# sale_date  Wed May 21 00:00:00 EDT 2008  Wed May 21 00:00:00 EDT 2008
# price                             59222                         68212
# latitude                      38.631913                     38.478902
# longitude                   -121.434879                   -121.431028
#
# ...

# %% [markdown]
# ## loading csv file via url using pandas

# %%
df_of_url = pd.read_csv('https://support.spatialkey.com/wp-content/uploads/2021/02/SalesJan2009.csv')
df_of_url
# Out:
#      Transaction_date   Product  Price Payment_Type               Name  \
# 0    01/02/2009 04:53  Product1   1200         Visa             Betina
# 1    01/02/2009 13:08  Product1   1200   Mastercard  Federica e Andrea
# 2    01/04/2009 12:56  Product2   3600         Visa             Gerd W
# 3    01/04/2009 13:19  Product1   1200         Visa           LAURENCE
# 4    01/04/2009 20:11  Product1   1200   Mastercard              Fleur
# ..                ...       ...    ...          ...                ...
# 993  01/02/2009 17:24  Product2   3600       Diners              clara
# 994  01/04/2009 18:57  Product1   1200   Mastercard               KELI
# 995  01/23/2009 12:42  Product2   3600   Mastercard               Anke
# 996  01/07/2009 19:48  Product2   3600   Mastercard             TRICIA
# 997  01/25/2009 05:57  Product1   1200         Amex             pamela
#
#                City              State        Country  Account_Created  \
# ...
